# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemant2000-karens/TinyML/blob/main/lab1_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1 Assignment
# ### Hemant Kumar
#
# ##### Implement a Regression using Single-Layer Neural Network. Take two set x and y and trained the model to find out the correct y=function of x. Already we discussed these in our previous lectures.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate synthetic data
np.random.seed(0)
x = np.random.rand(100, 1)  # 100 data points
y = 2 * x + 1 + np.random.randn(100, 1) * 0.1  # y = 2x + 1 with noise

# Plot the data
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Generated Data')
plt.show()

# Define the model
model = Sequential()
model.add(Dense(1, input_dim=1))  # Single layer with one neuron

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train the model
model.fit(x, y, epochs=100, verbose=1)

# Evaluate the model
loss = model.evaluate(x, y)
print(f'Loss: {loss}')

# Make predictions
y_pred = model.predict(x)

# Plot the results
plt.scatter(x, y, label='True data')
plt.plot(x, y_pred, color='red', label='Predicted line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Regression with Single-Layer Neural Network')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 13ms/step - loss: 3.7040
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 3.0495
# Epoch 3/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5348
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.0878
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.7309
# Epoch 6/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.4268
# Epoch 7/100
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2049
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9952
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8277
# Epoch 10/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.6931
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5766
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4754
# ...
